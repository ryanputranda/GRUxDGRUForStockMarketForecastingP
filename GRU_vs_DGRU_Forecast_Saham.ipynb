# %%
import pandas as pd

df = pd.read_excel('dataset.xlsx')

df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-01-02  3250000000  3250000000  3200000000  3250000000  3152056152
# 1 2020-01-03  3300000000  3300000000  3200000000  3290000000  3190850586
# 2 2020-01-06  3250000000  3280000000  3240000000  3280000000  3181152100
# 3 2020-01-07  3220000000  3240000000  3220000000  3240000000  3142357422
# 4 2020-01-08  3240000000  3240000000  3200000000  3240000000  3142357422
#
#    Volume
# 0    3700
# 1   11200
# 2   12000
# 3     300
# 4    1500

# %%
df = df.drop(['Adj Close', 'Volume'], axis=1)
df.head()
# Out:
#         Date        Open        High         Low       Close
# 0 2020-01-02  3250000000  3250000000  3200000000  3250000000
# 1 2020-01-03  3300000000  3300000000  3200000000  3290000000
# 2 2020-01-06  3250000000  3280000000  3240000000  3280000000
# 3 2020-01-07  3220000000  3240000000  3220000000  3240000000
# 4 2020-01-08  3240000000  3240000000  3200000000  3240000000

# %%
dfpake = df.copy()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))
plt.plot(dfpake['Date'], dfpake['Close'])

plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price Over Time')
plt.grid(True)

plt.xticks(rotation=45)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

dfpake['Smoothing'] = dfpake['Close'].rolling(window=20).mean()
plt.figure(figsize=(12, 6))
plt.plot(dfpake['Date'], dfpake['Close'], label='Close Price')
plt.plot(dfpake['Date'], dfpake['Smoothing'], label='Moving Average Smoothing')

plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price and 5-Day Moving Average')
plt.grid(True)
plt.legend()

plt.xticks(rotation=45)
plt.show()

# %%
dfpake.head(20)
# Out:
#          Date        Open        High         Low       Close     Smoothing
# 0  2020-01-02  3250000000  3250000000  3200000000  3250000000           NaN
# 1  2020-01-03  3300000000  3300000000  3200000000  3290000000           NaN
# 2  2020-01-06  3250000000  3280000000  3240000000  3280000000           NaN
# 3  2020-01-07  3220000000  3240000000  3220000000  3240000000           NaN
# 4  2020-01-08  3240000000  3240000000  3200000000  3240000000           NaN
# 5  2020-01-09  3200000000  3240000000  3200000000  3240000000           NaN
# 6  2020-01-10  3240000000  3250000000  3200000000  3250000000           NaN
# 7  2020-01-13  3250000000  3250000000  3180000000  3240000000           NaN
# 8  2020-01-14  3240000000  3240000000  3100000000  3100000000           NaN
# 9  2020-01-15  3110000000  3200000000  3090000000  3200000000           NaN
# 10 2020-01-16  3150000000  3270000000  3100000000  3170000000           NaN
# ...

# %%
dfpaketraining = dfpake.copy()

# %%
dfpaketraining = dfpaketraining.drop(dfpaketraining.index[0:19])

# %%
dfpaketraining
# Out:
#           Date        Open        High         Low       Close     Smoothing
# 19  2020-01-29  2990000000  3050000000  2950000000  2970000000  3.149000e+09
# 20  2020-01-30  2970000000  3060000000  2970000000  3060000000  3.139500e+09
# 21  2020-01-31  3000000000  3000000000  2900000000  2910000000  3.120500e+09
# 22  2020-02-03  2910000000  2980000000  2900000000  2980000000  3.105500e+09
# 23  2020-02-04  2980000000  2990000000  2940000000  2940000000  3.090500e+09
# ..         ...         ...         ...         ...         ...           ...
# 969 2023-12-21  2630000000  2630000000  2610000000  2630000000  2.640500e+09
# 970 2023-12-22  2630000000  2630000000  2600000000  2620000000  2.639500e+09
# 971 2023-12-27  2620000000  2650000000  2590000000  2640000000  2.639000e+09
# 972 2023-12-28  2640000000  2640000000  2600000000  2630000000  2.637000e+09
# 973 2023-12-29  2630000000  2630000000  2600000000  2620000000  2.633000e+09
#
# [955 rows x 6 columns]

# %% [markdown]
# ---

# %% [markdown]
# # **ALGORITMA GRU**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


data = dfpaketraining[['Smoothing']].values

scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

train_size = int(len(data_scaled) * 0.8)
train_data, test_data = data_scaled[:train_size], data_scaled[train_size:]

def create_sequences(data, seq_length=10):
    sequences, targets = [], []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        targets.append(data[i+seq_length])
    return np.array(sequences), np.array(targets)

seq_length = 10
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

model = Sequential([
    GRU(128, activation='tanh', return_sequences=True, input_shape=(seq_length, 1)),  # Input layer
    GRU(64, activation='tanh'),
    Dense(1)  # Output layer
])


learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='mse')

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=16,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time
print(f"Waktu Training: {training_time:.2f} detik")


y_pred = model.predict(X_test)


y_pred_original = scaler.inverse_transform(y_pred.reshape(-1, 1))
y_test_original = scaler.inverse_transform(y_test.reshape(-1, 1))


plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Grafik Loss selama Training')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0690 - val_loss: 1.0713e-04 - learning_rate: 0.0010
# Epoch 2/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0012 - val_loss: 6.9591e-05 - learning_rate: 0.0010
# Epoch 3/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3548e-04 - val_loss: 6.3001e-05 - learning_rate: 0.0010
# Epoch 4/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2423e-04 - val_loss: 1.5545e-04 - learning_rate: 0.0010
# Epoch 5/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4789e-04 - val_loss: 1.4097e-04 - learning_rate: 0.0010
# Epoch 6/200
# ...

# %%
mape = np.mean(np.abs((y_test_original - y_pred_original) / y_test_original)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MAPE: 0.09%

# %%
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test_original, y_pred_original))
rmse_percentage = (rmse / np.mean(y_test_original)) * 100
print(f"RMSE Percentage: {rmse_percentage:.2f}%")
# Out:
# RMSE Percentage: 0.11%

# %%
import pandas as pd
import numpy as np
import random
random_indices = random.sample(range(len(X_test)), 10)

predictions = []

for i in random_indices:
  prediction = model.predict(np.expand_dims(X_test[i], axis=0))
  predicted_value = scaler.inverse_transform(prediction.reshape(-1, 1))[0,0]
  date_index = i + train_size + seq_length
  date = dfpaketraining['Date'].iloc[date_index]
  actual_close = dfpaketraining['Close'].iloc[date_index]
  predictions.append([date, actual_close, predicted_value])

prediction_df = pd.DataFrame(predictions, columns=['Date', 'Close', 'Forecast'])
prediction_df
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#         Date       Close      Forecast
# 0 2023-12-01  2670000000  2.631043e+09
# 1 2023-05-03  2480000000  2.512127e+09
# 2 2023-10-03  2700000000  2.721676e+09
# 3 2023-08-23  2730000000  2.745245e+09
# 4 2023-07-06  2780000000  2.654487e+09
# 5 2023-09-22  2730000000  2.729637e+09
# 6 2023-10-30  2550000000  2.630834e+09
# 7 2023-08-04  2730000000  2.743450e+09
# 8 2023-10-13  2660000000  2.698140e+09
# 9 2023-09-29  2700000000  2.725480e+09

# %% [markdown]
# ---

# %% [markdown]
# # **ALGORITMA DGRU**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

data = dfpaketraining[['Smoothing']].values

scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

train_size = int(len(data_scaled) * 0.8)
train_data, test_data = data_scaled[:train_size], data_scaled[train_size:]

def create_sequences(data, seq_length=10):
    sequences, targets = [], []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i+seq_length])
        targets.append(data[i+seq_length])
    return np.array(sequences), np.array(targets)

seq_length = 10
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

X_train = X_train.reshape(X_train.shape[0], seq_length, 1)
X_test = X_test.reshape(X_test.shape[0], seq_length, 1)

model = Sequential([
    GRU(256, activation='tanh', return_sequences=True, input_shape=(seq_length, 1)),
    Dropout(0.3),
    GRU(128, activation='tanh', return_sequences=True),
    Dropout(0.3),
    GRU(64, activation='tanh'),
    Dropout(0.2),
    Dense(1)  # Layer output
])

learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)

model.compile(optimizer=optimizer, loss='mse')

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

start_time = time.time()

history = model.fit(
    X_train, y_train,
    epochs=200, batch_size=16,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time
print(f"Waktu Training: {training_time:.2f} detik")

y_pred = model.predict(X_test)

y_pred_original = scaler.inverse_transform(y_pred.reshape(-1, 1))
y_test_original = scaler.inverse_transform(y_test.reshape(-1, 1))


plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Grafik Loss selama Training')
plt.show()
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0501 - val_loss: 1.0927e-04 - learning_rate: 0.0010
# Epoch 2/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0044 - val_loss: 4.2820e-04 - learning_rate: 0.0010
# Epoch 3/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0046 - val_loss: 9.8330e-05 - learning_rate: 0.0010
# Epoch 4/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0041 - val_loss: 3.5499e-04 - learning_rate: 0.0010
# Epoch 5/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0038 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 6/200
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.0031 - val_loss: 0.0036 - learning_rate: 0.0010
# ...

# %%
mape = np.mean(np.abs((y_test_original - y_pred_original) / y_test_original)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MAPE: 0.19%

# %%
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test_original, y_pred_original))
rmse_percentage = (rmse / np.mean(y_test_original)) * 100
print(f"RMSE Percentage: {rmse_percentage:.2f}%")
# Out:
# RMSE Percentage: 0.25%

# %%
import pandas as pd
import numpy as np

random_indices = random.sample(range(len(X_test)), 10)

predictions = []

for i in random_indices:
  prediction = model.predict(np.expand_dims(X_test[i], axis=0))
  predicted_value = scaler.inverse_transform(prediction.reshape(-1, 1))[0,0]
  date_index = i + train_size + seq_length
  date = dfpaketraining['Date'].iloc[date_index]
  actual_close = dfpaketraining['Close'].iloc[date_index]
  predictions.append([date, actual_close, predicted_value])

prediction_df = pd.DataFrame(predictions, columns=['Date', 'Close', 'Forecast'])
prediction_df
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#         Date       Close      Forecast
# 0 2023-06-23  2680000000  2.606704e+09
# 1 2023-08-31  2740000000  2.743805e+09
# 2 2023-09-07  2730000000  2.744124e+09
# 3 2023-11-17  2630000000  2.588193e+09
# 4 2023-06-21  2660000000  2.595472e+09
# 5 2023-07-04  2770000000  2.626409e+09
# 6 2023-04-11  2500000000  2.480968e+09
# 7 2023-08-23  2730000000  2.745530e+09
# 8 2023-09-12  2720000000  2.738032e+09
# 9 2023-09-08  2730000000  2.742222e+09
